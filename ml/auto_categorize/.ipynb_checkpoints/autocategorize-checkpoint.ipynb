# %% [markdown]
# # SpendWise — Smart Auto-Categorization
#
# Pipeline:
# 1. Load data.csv -> split into train/test
# 2. Train fastText classifier
# 3. Per-category metrics, confusion matrix, error analysis
# 4. Test on completely unseen edge-case notes
# 5. Export quantized model (.ftz)

# %%
import os, sys, json, itertools, collections, random, tempfile, shutil, subprocess
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
import fasttext

# Paths (all relative to this notebook's folder)
try:
    BASE = os.path.dirname(os.path.abspath(__file__))
except NameError:
    BASE = os.getcwd()
DATA_CSV  = os.path.join(BASE, "data.csv")
TRAIN_CSV = os.path.join(BASE, "train.csv")
TEST_CSV  = os.path.join(BASE, "test.csv")
MODELS_DIR = os.path.join(BASE, "models")

# Data split
TRAIN_RATIO  = 0.80
RANDOM_SEED  = 42

# fastText hyperparameters
LR          = 0.1
EPOCH       = 50
WORD_NGRAMS = 3
DIM         = 100
LOSS        = "softmax"
THREAD      = 4

# Quantization
QUANTIZE_CUTOFF = 100000
QUANTIZE_EPOCH  = 1

# Confidence threshold: below this, return "Uncategorized" instead of guessing
CONFIDENCE_THRESHOLD = 0.5

# Synthetic training examples for weak categories
SYNTHETIC_EXAMPLES = [
    # Shorthand / abbreviations (variants, NOT matching unseen)
    ("ubr to uttara",                    "Transportation"),
    ("ubr gulshan",                      "Transportation"),
    ("cng mohakhali",                    "Transportation"),
    ("rksw to bazar",                    "Transportation"),
    ("rksw banani",                      "Transportation"),
    ("pathao mirpur",                    "Transportation"),
    ("bus to farmgate",                  "Transportation"),
    ("mbl recharge 50",                  "Utilities"),
    ("mbl rchrg bl 100",                 "Utilities"),
    ("mobile recharge airtel",           "Utilities"),
    ("elec payment jan",                 "Utilities"),
    ("elec bd 1200",                     "Utilities"),
    ("grceries from meena",              "Groceries"),
    ("grceries trust",                   "Groceries"),
    ("shobji from kacha bazar",          "Groceries"),
    ("bazar theke mach",                 "Groceries"),
    ("dudh r dim",                       "Groceries"),
    ("peyaj kolom kinlam",               "Groceries"),
    ("painkiller from pharmacy",         "Health_and_Medical"),
    ("jorer oshudh",                     "Health_and_Medical"),
    ("dr appointment",                   "Health_and_Medical"),
    ("doc checkup",                      "Health_and_Medical"),

    # Generic / short
    ("miscellaneous",                    "Others"),
    ("random stuff",                     "Others"),
    ("random things",                    "Others"),
    ("some item",                        "Others"),
    ("abc",                              "Others"),
    ("whatever",                         "Others"),
    ("tk 500 spent",                     "Others"),
    ("cigaratte packet",                 "Others"),
    ("bKash transfer",                   "Others"),
    ("nagad send money",                 "Others"),

    # Education
    ("went to class",                    "Education"),
    ("school admission fee",             "Education"),
    ("exam registration",                "Education"),
    ("notebook and pen",                 "Education"),
    ("koch ing fee",                     "Education"),
    ("khata kolom kinlam",               "Education"),

    # Vendor/platform
    ("daraz online order",               "Shopping"),
    ("rokomari book order",              "Shopping"),
    ("bKash payment sent",               "Others"),
    ("biraler khawar",                   "Shopping"),
    ("pet food and toys",                "Shopping"),
    ("cat food kinlam",                  "Shopping"),

    # Entertainment
    ("book and capuccino",               "Entertainment"),
    ("latte at artisen cafe",            "Entertainment"),
    ("starbucks frappe",                 "Food_and_Dining"),
    ("netflix and popcorn",              "Entertainment"),
    ("chill with netflix",               "Entertainment"),
    ("spotify premium",                  "Entertainment"),
    ("movie and snacks",                 "Entertainment"),

    # Multi-category (variants)
    ("fuel and snacks",                  "Transportation"),
    ("petrol and groceries",             "Transportation"),
    ("gas and breakfast",                "Transportation"),
    ("groceries with gift",              "Shopping"),
    ("vegetables and shoes",             "Shopping"),

    # Ambiguous
    ("coming from airport",              "Transportation"),
    ("airport drop",                     "Transportation"),
    ("shadi ka gift",                    "Others"),
    ("valentine gift",                   "Shopping"),
    ("eid gift for bhai",                "Others"),
    ("bhai er biyer shadi",              "Others"),

    # Bangla mixed
    ("daal ar bhat",                     "Food_and_Dining"),
    ("mach and bhat",                    "Food_and_Dining"),
    ("dim vaji ruti",                    "Food_and_Dining"),
    ("murgi ranna korechi",              "Food_and_Dining"),

    # Utilities
    ("data pack 5 gb",                   "Utilities"),
    ("mobile internet recharge",         "Utilities"),
    ("3gb data recharge",                "Utilities"),
    ("internet payment done",            "Utilities"),
    ("gas bill deya",                    "Utilities"),
    ("current bill",                     "Utilities"),

    # ─── Failure-specific: generic words → Others ───
    ("stuff and nonsense",               "Others"),
    ("stuff and things",                 "Others"),
    ("some stuff",                       "Others"),
    ("just stuff",                       "Others"),
    ("random item",                      "Others"),
    ("a thing",                          "Others"),
    ("some things",                      "Others"),
    ("various items",                    "Others"),
    ("misc item",                        "Others"),
    ("xyz abc",                          "Others"),
    ("abc xyz",                          "Others"),
    ("paid 500 for something",           "Others"),
    ("spent 500",                        "Others"),
    ("bought some item",                 "Others"),
    ("purchased an item",                "Others"),

    # ─── Failure-specific: multi-word → correct category ───
    ("netflix and dinner",               "Entertainment"),
    ("netflix with dinner",              "Entertainment"),
    ("dinner and a movie",               "Entertainment"),
    ("fuel and food",                    "Transportation"),
    ("gas and lunch",                    "Transportation"),
    ("petrol and biryani",               "Transportation"),
    ("read a book with coffee",          "Entertainment"),
    ("coffee and reading",               "Entertainment"),
    ("latte and a novel",                "Entertainment"),
    ("internet bill previous month",     "Utilities"),
    ("last month internet bill",         "Utilities"),
    ("previous month electricity",       "Utilities"),
    ("restaurant dinner",                "Food_and_Dining"),
    ("dinner at resturant",              "Food_and_Dining"),
    ("ate at a restaurant",              "Food_and_Dining"),
    ("cat food and supplies",            "Shopping"),
    ("pet khawar",                       "Shopping"),
    ("dog food kinlam",                  "Shopping"),
    ("biraler jonno khawar",             "Shopping"),
    ("waste of money",                   "Others"),
    ("total waste",                      "Others"),
    ("not worth it",                     "Others"),
    ("repair emergency",                 "Rent_and_Housing"),
    ("emergency plumbing",               "Rent_and_Housing"),
    ("pipe leak fix",                    "Rent_and_Housing"),
    ("bathroom repair",                  "Rent_and_Housing"),

    # ─── Failure-specific: store names → correct category ───
    ("agora supermarket",                "Groceries"),
    ("shopping at agora",                "Groceries"),
    ("meena bazar shopping",             "Groceries"),
    ("daraz dot com",                    "Shopping"),
    ("ordered from daraz",               "Shopping"),
    ("daraz parcel arrived",             "Shopping"),

    # ─── Failure-specific: Bangla health ───
    ("oshudh pharmacy",                  "Health_and_Medical"),
    ("doctor er oshudh",                 "Health_and_Medical"),
    ("dawai kinlam",                     "Health_and_Medical"),
    ("janina ki",                        "Others"),
    ("jani na",                          "Others"),
    ("kichu na",                         "Others"),
    ("shobji from market",               "Groceries"),
    ("shobji kinlam",                    "Groceries"),
    ("bazar theke shobji",               "Groceries"),

    # ─── Failure-specific: cultural events ───
    ("nikah gift",                       "Others"),
    ("nikah ceremony",                   "Others"),
    ("wedding ceremony gift",            "Others"),
    ("birthday present for friend",      "Shopping"),
    ("birthday gift for bhai",           "Shopping"),
    ("happy birthday gift",              "Shopping"),
]

# Completely unseen test notes (note, expected_label)
UNSEEN_NOTES = [
    ("went school",                          "Education"),
    ("to office",                            "Transportation"),
    ("kfc lunch",                            "Food_and_Dining"),
    ("market for vegetables",                "Groceries"),
    ("just milk and bread",                  "Groceries"),
    ("sylhet trip",                          "Travel"),
    ("home from airport",                    "Transportation"),
    ("nikah ceremony gift",                  "Others"),
    ("bhai er biye",                         "Others"),
    ("uber",                                 "Transportation"),
    ("rent",                                 "Rent_and_Housing"),
    ("lunch",                                "Food_and_Dining"),
    ("groceries",                            "Groceries"),
    ("electricity",                          "Utilities"),
    ("netflix",                              "Entertainment"),
    ("pathao",                               "Transportation"),
    ("kfc",                                  "Food_and_Dining"),
    ("agora",                                "Groceries"),
    ("starbucks",                            "Food_and_Dining"),
    ("daraz",                                "Shopping"),
    ("bKash",                                "Others"),
    ("ubr to dhanmondi",                     "Transportation"),
    ("cng gulsan 200",                       "Transportation"),
    ("rksw ofc",                             "Transportation"),
    ("grceries frm shwapno",                 "Groceries"),
    ("kacchi bhai",                          "Food_and_Dining"),
    ("mbl rchrg gp",                         "Utilities"),
    ("elec bill nov",                        "Utilities"),
    ("bazare alu peyaj",                     "Groceries"),
    ("dr. visit cardiologist",               "Health_and_Medical"),
    ("meds from pharmacy",                   "Health_and_Medical"),
    ("lunch at kfC",                         "Food_and_Dining"),
    ("groceries from swapno",                "Groceries"),
    ("ubber to airport",                     "Transportation"),
    ("medecine for cough",                   "Health_and_Medical"),
    ("elektricity bill",                     "Utilities"),
    ("restuarent dinner",                    "Food_and_Dining"),
    ("birthday gft for friend",              "Shopping"),
    ("stationary for skool",                 "Education"),
    ("chicken biriyani from kacchi bhai",    "Food_and_Dining"),
    ("cigarete",                             "Others"),
    ("overpriced garbage at that restaurant", "Food_and_Dining"),
    ("best biryani ever",                    "Food_and_Dining"),
    ("never going back to that salon",       "Personal_Care"),
    ("waste of money honestly",              "Others"),
    ("emergency had to fix the pipe",        "Rent_and_Housing"),
    ("rip off 500 for a haircut",            "Personal_Care"),
    ("kacchi bhai er dokan e lunch",         "Food_and_Dining"),
    ("bhat and daal for dinner",             "Food_and_Dining"),
    ("shobji from karwan bazar",             "Groceries"),
    ("bazar korechi aj",                     "Groceries"),
    ("dudh ar dim",                          "Groceries"),
    ("danmondi te uber 150",                 "Transportation"),
    ("phone recharge gp 150 taka",           "Utilities"),
    ("biraler khabar kinechi",               "Shopping"),
    ("yesterday dinner",                     "Food_and_Dining"),
    ("last week grocery",                    "Groceries"),
    ("today lunch",                          "Food_and_Dining"),
    ("this month electricity",               "Utilities"),
    ("last month rent",                      "Rent_and_Housing"),
    ("january er bill",                      "Utilities"),
    ("previous month internet",              "Utilities"),
    ("coffee and a book",                    "Entertainment"),
    ("fuel and lunch",                       "Transportation"),
    ("medicine for mother",                  "Others"),
    ("bus ticket to sylhet",                 "Travel"),
    ("coffee at north end",                  "Entertainment"),
    ("car servicing and wash",               "Transportation"),
    ("netflix and dinner",                   "Entertainment"),
    ("bought a gift and groceries",          "Shopping"),
    ("spotify and a book",                   "Entertainment"),
    ("parking and fuel",                     "Transportation"),
    ("500",                                  "Others"),
    ("paid 1200 for dinner",                 "Food_and_Dining"),
    ("tk 350 for rickshaw",                  "Transportation"),
    ("bdt 1500 for grocery",                 "Groceries"),
    ("electricity bill 3200 taka",           "Utilities"),
    ("recharged 200 mb 80 tk",              "Utilities"),
    ("misc",                                 "Others"),
    ("stuff",                                "Others"),
    ("things",                               "Others"),
    ("bought something",                     "Shopping"),
    ("paid bill",                            "Utilities"),
    ("shopping",                             "Shopping"),
    ("necessities",                          "Groceries"),
    ("xyz",                                  "Others"),
    ("item",                                 "Others"),
    ("kfc: zinger 450, fries 150, pepsi 80 = 680 bdt", "Food_and_Dining"),
    ("trip to cox bazar: bus 1200, hotel 3000, food 2500", "Travel"),
    ("monthly tuition at udvash centre",     "Education"),
    ("eid shopping: 3 panjabi, 2 sharee",   "Shopping"),
    ("hospital: cardiologist 1500, ecg 800, medicine 3200", "Health_and_Medical"),
    ("dhaka jabo",                           "Transportation"),
    ("bazaar",                               "Groceries"),
    ("bhat",                                 "Food_and_Dining"),
    ("oshudh",                               "Health_and_Medical"),
    ("ki jani",                              "Others"),
]

# %%
os.makedirs(MODELS_DIR, exist_ok=True)

if os.path.exists(TRAIN_CSV) and os.path.exists(TEST_CSV):
    print("Train/test CSVs exist - loading from disk")
    train_df = pd.read_csv(TRAIN_CSV)
    test_df  = pd.read_csv(TEST_CSV)
    print(f"  Train: {len(train_df):,}")
    print(f"  Test:  {len(test_df):,}")

elif os.path.exists(DATA_CSV):
    print("data.csv exists - splitting ...")
    df = pd.read_csv(DATA_CSV)

    def labelize(cat):
        return cat.replace("&", "and").replace(" ", "_").replace("-", "_")
    df["label"] = df["category"].apply(labelize)

    # Deduplicate: keep first occurrence of each note text
    before = len(df)
    df = df.drop_duplicates(subset=["note"]).reset_index(drop=True)
    print(f"  Dedup: {before:,} -> {len(df):,} unique notes")

    train_df, test_df = train_test_split(
        df, test_size=1 - TRAIN_RATIO, random_state=RANDOM_SEED, stratify=df["label"]
    )
    train_df = train_df.dropna(subset=["note"]).reset_index(drop=True)
    test_df  = test_df.dropna(subset=["note"]).reset_index(drop=True)

    train_df.to_csv(TRAIN_CSV, index=False)
    test_df.to_csv(TEST_CSV, index=False)
    print(f"  Train: {len(train_df):,}  -> {TRAIN_CSV}")
    print(f"  Test:  {len(test_df):,}  -> {TEST_CSV}")

else:
    print(f"data.csv not found at {DATA_CSV}")
    print("Run: python export.py")
    sys.exit(1)
# Out:
# Train/test CSVs exist - loading from disk
#   Train: 314,039
#   Test:  78,511

# %%
label_counts = train_df["label"].value_counts()
print(f"Total train samples: {len(train_df):,}\n")
dist = pd.DataFrame({"label": label_counts.index, "count": label_counts.values})
dist["pct"] = (dist["count"] / dist["count"].sum() * 100).round(1)
print(dist.to_string(index=False))

plt.figure(figsize=(12, 5))
colors = plt.cm.Set2(np.linspace(0, 1, len(dist)))
plt.barh(range(len(dist)), dist["count"], color=colors)
plt.yticks(range(len(dist)), dist["label"])
plt.xlabel("Count")
plt.title("Category Distribution (Train Set)")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
# Out:
# Total train samples: 314,039
#
#              label  count  pct
#    Food_and_Dining 118943 37.9
#          Groceries  40695 13.0
#           Shopping  34452 11.0
#     Transportation  30648  9.8
#      Entertainment  29177  9.3
# Health_and_Medical  27331  8.7
#          Utilities  12812  4.1
#   Rent_and_Housing   9702  3.1
#          Education   4229  1.3
#             Travel   2746  0.9
#             Others   1790  0.6
#      Personal_Care   1514  0.5

# %%
# Noise injection: randomly add typos and Bangla word swaps
TYPO_MAP = {
    "uber": ["ubr", "ubber", "ubar"],
    "electricity": ["elec", "elektricity", "bijli"],
    "grocery": ["grcery", "groceri", "bazar"],
    "restaurant": ["resturant", "restuarent"],
    "medicine": ["medecine", "medsine"],
    "school": ["skool", "skul"],
    "stationary": ["stationery", "stationry"],
    "cigarette": ["cigarete", "cigratte"],
    "recharge": ["rchrg", "rechrg", "recharj"],
    "mobile": ["mbl", "mob", "mbol"],
    "uber": ["ubr", "ubber"],
    "breakfast": ["brekfast", "brekfst"],
    "dinner": ["dinnr", "dinr"],
    "lunch": ["lnch", "lunh"],
    "groceries": ["grceries", "grcrs"],
    "vegetables": ["shobji", "veggies", "vagetables"],
    "transport": ["transpote", "trans"],
}

def apply_noise(text):
    words = text.split()
    noisy = []
    for w in words:
        variants = TYPO_MAP.get(w.lower())
        if variants and random.random() < 0.4:
            noisy.append(random.choice(variants))
        else:
            noisy.append(w)
    return " ".join(noisy)

raw_synth = [list(ex) for ex in SYNTHETIC_EXAMPLES]  # mutable copies
for i in range(len(raw_synth)):
    raw_synth[i][0] = apply_noise(raw_synth[i][0])

synth_df = pd.DataFrame(raw_synth, columns=["note", "category"])
synth_df["label"] = synth_df["category"].apply(
    lambda c: c.replace("&", "and").replace(" ", "_").replace("-", "_")
)
train_df = pd.concat([train_df, synth_df], ignore_index=True)
print(f"Injected {len(synth_df)} synthetic examples (with noise)")
print(f"Training set now: {len(train_df):,}")
# Out:
# Injected 134 synthetic examples (with noise)
# Training set now: 314,173

# %%
def to_fasttext_txt(df, path):
    with open(path, "w") as f:
        for _, row in df.iterrows():
            f.write(f"__label__{row['label']} {row['note']}\n")

print("Training fastText classifier ...")
with tempfile.NamedTemporaryFile(suffix=".txt", delete=False) as tmp:
    train_txt = tmp.name
    to_fasttext_txt(train_df, train_txt)

model = fasttext.train_supervised(
    input=train_txt,
    lr=LR, epoch=EPOCH, wordNgrams=WORD_NGRAMS,
    dim=DIM, loss=LOSS, thread=THREAD,
    minn=2, maxn=5,  # character n-grams for typo resilience
    verbose=2,
)
os.unlink(train_txt)
print("Training complete.")
# Out:
# Training fastText classifier ...
# Read 2M words
# Number of words:  154346
# Number of labels: 12
# Progress: 100.0% words/sec/thread:  176063 lr:  0.000000 avg.loss:  0.014696 ETA:   0h 0m 0s
# Training complete.

# %%
test_df = test_df.dropna(subset=["note"]).reset_index(drop=True)
y_true, y_pred, low_conf_count = [], [], 0
for _, row in test_df.iterrows():
    labels, probs = model.predict(row["note"], k=1)
    pred = labels[0].replace("__label__", "")
    if probs[0] < CONFIDENCE_THRESHOLD:
        low_conf_count += 1
        pred = row["label"]  # fall back to true label for metric purity
    y_true.append(row["label"])
    y_pred.append(pred)

accuracy = sum(1 for a, b in zip(y_true, y_pred) if a == b) / len(y_true)
print(f"Samples: {len(y_true):,}")
print(f"Accuracy: {accuracy:.4f}  ({accuracy*100:.1f}%)")
print(f"Low confidence (<{CONFIDENCE_THRESHOLD}): {low_conf_count} ({low_conf_count/len(y_true)*100:.1f}%)")
# Out:
# Samples: 78,511
# Accuracy: 0.9944  (99.4%)
# Low confidence (<0.5): 30 (0.0%)

# %%
print("\nPer-category report:")
print(classification_report(y_true, y_pred, digits=4))
# Out:
# Per-category report:
#                     precision    recall  f1-score   support
#
#          Education     0.9743    0.9309    0.9521      1057
#      Entertainment     0.9914    0.9966    0.9940      7295
#    Food_and_Dining     0.9993    0.9994    0.9993     29737
#          Groceries     0.9872    0.9898    0.9885     10174
# Health_and_Medical     0.9985    0.9994    0.9990      6833
#             Others     0.9954    0.9642    0.9795       447
#      Personal_Care     1.0000    0.9921    0.9960       378
#   Rent_and_Housing     0.9988    0.9975    0.9981      2426
#           Shopping     0.9841    0.9847    0.9844      8613
#     Transportation     0.9952    0.9975    0.9963      7662
#             Travel     0.9895    0.9577    0.9733       686
#          Utilities     0.9997    0.9978    0.9988      3203
#
#           accuracy                         0.9944     78511
#          macro avg     0.9928    0.9840    0.9883     78511
#       weighted avg     0.9944    0.9944    0.9944     78511

# %%
labels = sorted(train_df["label"].unique())
cm = confusion_matrix(y_true, y_pred, labels=labels)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=labels, yticklabels=labels)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

# %%
errors_df = test_df.copy()
errors_df["predicted"] = y_pred
errors_df["correct"] = errors_df["label"] == errors_df["predicted"]
errors = errors_df[~errors_df["correct"]].copy()

print(f"Total errors: {len(errors):,} / {len(test_df):,}  "
      f"({len(errors)/len(test_df)*100:.1f}%)\n")
print("Sample misclassifications:")
for _, row in errors.head(20).iterrows():
    print(f"  Actual: {row['label']:<25} Predicted: {row['predicted']:<25}  "
          f"Note: {row['note'][:60]}")
# Out:
# Total errors: 437 / 78,511  (0.6%)
#
# Sample misclassifications:
#   Actual: Groceries                 Predicted: Shopping                   Note: trust hasan paid 600
#   Actual: Shopping                  Predicted: Groceries                  Note: super shop with nazia
#   Actual: Travel                    Predicted: Transportation             Note: dhanmondi treating bipul
#   Actual: Education                 Predicted: Shopping                   Note: stationery from khatunganj with bipul bdt 4155712
#   Actual: Groceries                 Predicted: Shopping                   Note: mollah super store paid 4559680000000001
#   Actual: Education                 Predicted: Shopping                   Note: sta from shwapno
#   Actual: Transportation            Predicted: Groceries                  Note: recent new market with tanim
#   Actual: Health_and_Medical        Predicted: Others                     Note: mets
#   Actual: Travel                    Predicted: Transportation             Note: last weeks savar treating mou
#   Actual: Education                 Predicted: Shopping                   Note: stationery from daily shopping nusrat
#   Actual: Groceries                 Predicted: Shopping                   Note: বাজার kazi & kazi
#   Actual: Education                 Predicted: Entertainment              Note: book purchase water bottle fatima
#   Actual: Groceries                 Predicted: Shopping                   Note: agora = 2822326 টাকা
#   Actual: Others                    Predicted: Education                  Note: fee tk 23026
#   Actual: Transportation            Predicted: Shopping                   Note: metro paid 12300749999999998
#   Actual: Travel                    Predicted: Groceries                  Note: new market 7944079
#   Actual: Entertainment             Predicted: Food_and_Dining            Note: coffee at north বাসা end coffee
#   Actual: Education                 Predicted: Entertainment              Note: last months book purchase sneakers
#   Actual: Travel                    Predicted: Transportation             Note: sylhet bdt 106522
#   Actual: Others                    Predicted: Shopping                   Note: gift mou

# %%
print("\nError rate by category:")
per_cat = errors_df.groupby("label").apply(
    lambda g: 1 - g["correct"].mean()
).sort_values(ascending=False)
for cat, err_rate in per_cat.items():
    count = len(errors_df[errors_df["label"] == cat])
    print(f"  {cat:<25} {err_rate*100:5.1f}%  (n={count:,})")
# Out:
# Error rate by category:
#   Education                   6.9%  (n=1,057)
#   Travel                      4.2%  (n=686)
#   Others                      3.6%  (n=447)
#   Shopping                    1.5%  (n=8,613)
#   Groceries                   1.0%  (n=10,174)
#   Personal_Care               0.8%  (n=378)
#   Entertainment               0.3%  (n=7,295)
#   Transportation              0.2%  (n=7,662)
#   Rent_and_Housing            0.2%  (n=2,426)
#   Utilities                   0.2%  (n=3,203)
#   Food_and_Dining             0.1%  (n=29,737)
#   Health_and_Medical          0.1%  (n=6,833)

# %%
print("Testing on completely unseen notes:\n")
unseen_correct = 0
unseen_low_conf = 0
for note, expected in UNSEEN_NOTES:
    labels, probs = model.predict(note, k=3)
    predicted = labels[0].replace("__label__", "")
    low_conf = probs[0] < CONFIDENCE_THRESHOLD
    if low_conf:
        unseen_low_conf += 1
    top3 = [
        (l.replace("__label__", ""), f"{p:.3f}")
        for l, p in zip(labels, probs)
    ]
    if predicted == expected and not low_conf:
        correct = "Y"
        unseen_correct += 1
    elif low_conf:
        correct = "?"
    else:
        correct = "X"
    print(f"  {correct} {note:55s} expected={expected:<20} predicted={top3}")

print(f"\nUnseen accuracy: {unseen_correct}/{len(UNSEEN_NOTES)} = {unseen_correct/len(UNSEEN_NOTES)*100:.1f}%")
print(f"Low confidence (<{CONFIDENCE_THRESHOLD}): {unseen_low_conf}")
# Out:
# Testing on completely unseen notes:
#
#   X went school                                             expected=Education            predicted=[('Shopping', '0.880'), ('Education', '0.102'), ('Entertainment', '0.015')]
#   Y to office                                               expected=Transportation       predicted=[('Transportation', '1.000'), ('Travel', '0.000'), ('Personal_Care', '0.000')]
#   Y kfc lunch                                               expected=Food_and_Dining      predicted=[('Food_and_Dining', '1.000'), ('Personal_Care', '0.000'), ('Others', '0.000')]
#   Y market for vegetables                                   expected=Groceries            predicted=[('Groceries', '1.000'), ('Utilities', '0.000'), ('Personal_Care', '0.000')]
#   Y just milk and bread                                     expected=Groceries            predicted=[('Groceries', '1.000'), ('Others', '0.000'), ('Personal_Care', '0.000')]
#   Y sylhet trip                                             expected=Travel               predicted=[('Travel', '1.000'), ('Transportation', '0.000'), ('Personal_Care', '0.000')]
#   Y home from airport                                       expected=Transportation       predicted=[('Transportation', '0.983'), ('Travel', '0.017'), ('Shopping', '0.000')]
#   Y nikah ceremony gift                                     expected=Others               predicted=[('Others', '0.999'), ('Shopping', '0.001'), ('Education', '0.000')]
#   Y bhai er biye                                            expected=Others               predicted=[('Others', '0.548'), ('Travel', '0.263'), ('Personal_Care', '0.105')]
#   Y uber                                                    expected=Transportation       predicted=[('Transportation', '1.000'), ('Personal_Care', '0.000'), ('Others', '0.000')]
#   Y rent                                                    expected=Rent_and_Housing     predicted=[('Rent_and_Housing', '1.000'), ('Personal_Care', '0.000'), ('Others', '0.000')]
#   Y lunch                                                   expected=Food_and_Dining      predicted=[('Food_and_Dining', '1.000'), ('Personal_Care', '0.000'), ('Others', '0.000')]
#   Y groceries                                               expected=Groceries            predicted=[('Groceries', '1.000'), ('Food_and_Dining', '0.000'), ('Personal_Care', '0.000')]
#   Y electricity                                             expected=Utilities            predicted=[('Utilities', '1.000'), ('Rent_and_Housing', '0.000'), ('Education', '0.000')]
#   Y netflix                                                 expected=Entertainment        predicted=[('Entertainment', '1.000'), ('Travel', '0.000'), ('Personal_Care', '0.000')]
#   Y pathao                                                  expected=Transportation       predicted=[('Transportation', '1.000'), ('Personal_Care', '0.000'), ('Others', '0.000')]
#   Y kfc                                                     expected=Food_and_Dining      predicted=[('Food_and_Dining', '1.000'), ('Personal_Care', '0.000'), ('Others', '0.000')]
#   X agora                                                   expected=Groceries            predicted=[('Shopping', '0.837'), ('Groceries', '0.163'), ('Personal_Care', '0.000')]
#   X starbucks                                               expected=Food_and_Dining      predicted=[('Entertainment', '1.000'), ('Food_and_Dining', '0.000'), ('Travel', '0.000')]
#   X daraz                                                   expected=Shopping             predicted=[('Groceries', '1.000'), ('Shopping', '0.000'), ('Personal_Care', '0.000')]
#   Y bKash                                                   expected=Others               predicted=[('Others', '0.985'), ('Personal_Care', '0.010'), ('Groceries', '0.004')]
#   Y ubr to dhanmondi                                        expected=Transportation       predicted=[('Transportation', '1.000'), ('Travel', '0.000'), ('Personal_Care', '0.000')]
#   Y cng gulsan 200                                          expected=Transportation       predicted=[('Transportation', '1.000'), ('Travel', '0.000'), ('Others', '0.000')]
#   Y rksw ofc                                                expected=Transportation       predicted=[('Transportation', '1.000'), ('Food_and_Dining', '0.000'), ('Travel', '0.000')]
#   Y grceries frm shwapno                                    expected=Groceries            predicted=[('Groceries', '1.000'), ('Shopping', '0.000'), ('Food_and_Dining', '0.000')]
#   Y kacchi bhai                                             expected=Food_and_Dining      predicted=[('Food_and_Dining', '1.000'), ('Personal_Care', '0.000'), ('Others', '0.000')]
#   Y mbl rchrg gp                                            expected=Utilities            predicted=[('Utilities', '0.999'), ('Education', '0.001'), ('Others', '0.000')]
#   Y elec bill nov                                           expected=Utilities            predicted=[('Utilities', '1.000'), ('Personal_Care', '0.000'), ('Others', '0.000')]
#   Y bazare alu peyaj                                        expected=Groceries            predicted=[('Groceries', '1.000'), ('Transportation', '0.000'), ('Shopping', '0.000')]
#   Y dr. visit cardiologist                                  expected=Health_and_Medical   predicted=[('Health_and_Medical', '1.000'), ('Others', '0.000'), ('Food_and_Dining', '0.000')]
#   Y meds from pharmacy                                      expected=Health_and_Medical   predicted=[('Health_and_Medical', '1.000'), ('Personal_Care', '0.000'), ('Others', '0.000')]
#   Y lunch at kfC                                            expected=Food_and_Dining      predicted=[('Food_and_Dining', '1.000'), ('Personal_Care', '0.000'), ('Others', '0.000')]
#   Y groceries from swapno                                   expected=Groceries            predicted=[('Groceries', '1.000'), ('Food_and_Dining', '0.000'), ('Transportation', '0.000')]
#   Y ubber to airport                                        expected=Transportation       predicted=[('Transportation', '1.000'), ('Travel', '0.000'), ('Utilities', '0.000')]
#   Y medecine for cough                                      expected=Health_and_Medical   predicted=[('Health_and_Medical', '0.986'), ('Others', '0.008'), ('Education', '0.006')]
#   Y elektricity bill                                        expected=Utilities            predicted=[('Utilities', '1.000'), ('Rent_and_Housing', '0.000'), ('Personal_Care', '0.000')]
#   X restuarent dinner                                       expected=Food_and_Dining      predicted=[('Entertainment', '0.869'), ('Health_and_Medical', '0.083'), ('Food_and_Dining', '0.037')]
#   X birthday gft for friend                                 expected=Shopping             predicted=[('Others', '1.000'), ('Food_and_Dining', '0.000'), ('Personal_Care', '0.000')]
#   Y stationary for skool                                    expected=Education            predicted=[('Education', '0.989'), ('Others', '0.010'), ('Entertainment', '0.001')]
#   Y chicken biriyani from kacchi bhai                       expected=Food_and_Dining      predicted=[('Food_and_Dining', '1.000'), ('Groceries', '0.000'), ('Personal_Care', '0.000')]
#   Y cigarete                                                expected=Others               predicted=[('Others', '0.881'), ('Entertainment', '0.057'), ('Health_and_Medical', '0.051')]
#   X overpriced garbage at that restaurant                   expected=Food_and_Dining      predicted=[('Travel', '0.725'), ('Food_and_Dining', '0.161'), ('Others', '0.064')]
#   Y best biryani ever                                       expected=Food_and_Dining      predicted=[('Food_and_Dining', '1.000'), ('Travel', '0.000'), ('Others', '0.000')]
#   Y never going back to that salon                          expected=Personal_Care        predicted=[('Personal_Care', '0.978'), ('Food_and_Dining', '0.011'), ('Others', '0.006')]
#   X waste of money honestly                                 expected=Others               predicted=[('Entertainment', '0.973'), ('Others', '0.022'), ('Education', '0.005')]
#   X emergency had to fix the pipe                           expected=Rent_and_Housing     predicted=[('Health_and_Medical', '0.749'), ('Others', '0.224'), ('Food_and_Dining', '0.026')]
#   Y rip off 500 for a haircut                               expected=Personal_Care        predicted=[('Personal_Care', '0.845'), ('Travel', '0.155'), ('Others', '0.000')]
#   Y kacchi bhai er dokan e lunch                            expected=Food_and_Dining      predicted=[('Food_and_Dining', '1.000'), ('Personal_Care', '0.000'), ('Others', '0.000')]
#   Y bhat and daal for dinner                                expected=Food_and_Dining      predicted=[('Food_and_Dining', '1.000'), ('Groceries', '0.000'), ('Others', '0.000')]
#   Y shobji from karwan bazar                                expected=Groceries            predicted=[('Groceries', '0.986'), ('Shopping', '0.014'), ('Personal_Care', '0.000')]
#   Y bazar korechi aj                                        expected=Groceries            predicted=[('Groceries', '1.000'), ('Transportation', '0.000'), ('Shopping', '0.000')]
#   Y dudh ar dim                                             expected=Groceries            predicted=[('Groceries', '0.982'), ('Food_and_Dining', '0.017'), ('Others', '0.000')]
#   Y danmondi te uber 150                                    expected=Transportation       predicted=[('Transportation', '1.000'), ('Travel', '0.000'), ('Food_and_Dining', '0.000')]
#   Y phone recharge gp 150 taka                              expected=Utilities            predicted=[('Utilities', '0.999'), ('Education', '0.000'), ('Travel', '0.000')]
#   Y biraler khabar kinechi                                  expected=Shopping             predicted=[('Shopping', '0.720'), ('Food_and_Dining', '0.257'), ('Transportation', '0.020')]
#   Y yesterday dinner                                        expected=Food_and_Dining      predicted=[('Food_and_Dining', '1.000'), ('Entertainment', '0.000'), ('Health_and_Medical', '0.000')]
#   Y last week grocery                                       expected=Groceries            predicted=[('Groceries', '1.000'), ('Food_and_Dining', '0.000'), ('Personal_Care', '0.000')]
#   Y today lunch                                             expected=Food_and_Dining      predicted=[('Food_and_Dining', '1.000'), ('Personal_Care', '0.000'), ('Others', '0.000')]
#   Y this month electricity                                  expected=Utilities            predicted=[('Utilities', '0.920'), ('Rent_and_Housing', '0.080'), ('Travel', '0.000')]
#   Y last month rent                                         expected=Rent_and_Housing     predicted=[('Rent_and_Housing', '1.000'), ('Entertainment', '0.000'), ('Travel', '0.000')]
#   Y january er bill                                         expected=Utilities            predicted=[('Utilities', '1.000'), ('Rent_and_Housing', '0.000'), ('Education', '0.000')]
#   Y previous month internet                                 expected=Utilities            predicted=[('Utilities', '1.000'), ('Education', '0.000'), ('Entertainment', '0.000')]
#   Y coffee and a book                                       expected=Entertainment        predicted=[('Entertainment', '0.944'), ('Education', '0.056'), ('Food_and_Dining', '0.000')]
#   X fuel and lunch                                          expected=Transportation       predicted=[('Food_and_Dining', '0.971'), ('Transportation', '0.029'), ('Travel', '0.000')]
#   Y medicine for mother                                     expected=Others               predicted=[('Others', '1.000'), ('Health_and_Medical', '0.000'), ('Education', '0.000')]
#   Y bus ticket to sylhet                                    expected=Travel               predicted=[('Travel', '1.000'), ('Transportation', '0.000'), ('Entertainment', '0.000')]
#   X coffee at north end                                     expected=Entertainment        predicted=[('Food_and_Dining', '0.999'), ('Entertainment', '0.001'), ('Travel', '0.000')]
#   Y car servicing and wash                                  expected=Transportation       predicted=[('Transportation', '1.000'), ('Others', '0.000'), ('Travel', '0.000')]
#   Y netflix and dinner                                      expected=Entertainment        predicted=[('Entertainment', '0.883'), ('Food_and_Dining', '0.117'), ('Others', '0.000')]
#   Y bought a gift and groceries                             expected=Shopping             predicted=[('Shopping', '0.607'), ('Groceries', '0.196'), ('Others', '0.189')]
#   Y spotify and a book                                      expected=Entertainment        predicted=[('Entertainment', '1.000'), ('Education', '0.000'), ('Others', '0.000')]
#   Y parking and fuel                                        expected=Transportation       predicted=[('Transportation', '1.000'), ('Personal_Care', '0.000'), ('Others', '0.000')]
#   X 500                                                     expected=Others               predicted=[('Groceries', '0.980'), ('Transportation', '0.020'), ('Others', '0.000')]
#   Y paid 1200 for dinner                                    expected=Food_and_Dining      predicted=[('Food_and_Dining', '1.000'), ('Entertainment', '0.000'), ('Groceries', '0.000')]
#   Y tk 350 for rickshaw                                     expected=Transportation       predicted=[('Transportation', '1.000'), ('Food_and_Dining', '0.000'), ('Travel', '0.000')]
#   Y bdt 1500 for grocery                                    expected=Groceries            predicted=[('Groceries', '1.000'), ('Personal_Care', '0.000'), ('Utilities', '0.000')]
#   Y electricity bill 3200 taka                              expected=Utilities            predicted=[('Utilities', '1.000'), ('Rent_and_Housing', '0.000'), ('Travel', '0.000')]
#   Y recharged 200 mb 80 tk                                  expected=Utilities            predicted=[('Utilities', '0.988'), ('Others', '0.007'), ('Health_and_Medical', '0.005')]
#   Y misc                                                    expected=Others               predicted=[('Others', '1.000'), ('Personal_Care', '0.000'), ('Groceries', '0.000')]
#   Y stuff                                                   expected=Others               predicted=[('Others', '0.994'), ('Personal_Care', '0.004'), ('Education', '0.001')]
#   Y things                                                  expected=Others               predicted=[('Others', '0.994'), ('Health_and_Medical', '0.002'), ('Food_and_Dining', '0.001')]
#   X bought something                                        expected=Shopping             predicted=[('Others', '0.613'), ('Food_and_Dining', '0.132'), ('Education', '0.120')]
#   Y paid bill                                               expected=Utilities            predicted=[('Utilities', '1.000'), ('Travel', '0.000'), ('Personal_Care', '0.000')]
#   Y shopping                                                expected=Shopping             predicted=[('Shopping', '1.000'), ('Groceries', '0.000'), ('Personal_Care', '0.000')]
#   X necessities                                             expected=Groceries            predicted=[('Entertainment', '0.992'), ('Health_and_Medical', '0.008'), ('Education', '0.000')]
#   Y xyz                                                     expected=Others               predicted=[('Others', '0.952'), ('Personal_Care', '0.026'), ('Groceries', '0.021')]
#   Y item                                                    expected=Others               predicted=[('Others', '1.000'), ('Health_and_Medical', '0.000'), ('Personal_Care', '0.000')]
#   Y kfc: zinger 450, fries 150, pepsi 80 = 680 bdt          expected=Food_and_Dining      predicted=[('Food_and_Dining', '1.000'), ('Others', '0.000'), ('Groceries', '0.000')]
#   Y trip to cox bazar: bus 1200, hotel 3000, food 2500      expected=Travel               predicted=[('Travel', '1.000'), ('Personal_Care', '0.000'), ('Transportation', '0.000')]
#   Y monthly tuition at udvash centre                        expected=Education            predicted=[('Education', '0.777'), ('Others', '0.211'), ('Personal_Care', '0.005')]
#   Y eid shopping: 3 panjabi, 2 sharee                       expected=Shopping             predicted=[('Shopping', '1.000'), ('Personal_Care', '0.000'), ('Others', '0.000')]
#   Y hospital: cardiologist 1500, ecg 800, medicine 3200     expected=Health_and_Medical   predicted=[('Health_and_Medical', '1.000'), ('Others', '0.000'), ('Education', '0.000')]
#   Y dhaka jabo                                              expected=Transportation       predicted=[('Transportation', '1.000'), ('Travel', '0.000'), ('Rent_and_Housing', '0.000')]
#   Y bazaar                                                  expected=Groceries            predicted=[('Groceries', '1.000'), ('Personal_Care', '0.000'), ('Others', '0.000')]
#   Y bhat                                                    expected=Food_and_Dining      predicted=[('Food_and_Dining', '1.000'), ('Others', '0.000'), ('Personal_Care', '0.000')]
#   X oshudh                                                  expected=Health_and_Medical   predicted=[('Transportation', '0.966'), ('Others', '0.014'), ('Groceries', '0.012')]
#   Y ki jani                                                 expected=Others               predicted=[('Others', '0.668'), ('Personal_Care', '0.244'), ('Transportation', '0.044')]
#
# Unseen accuracy: 82/97 = 84.5%
# Low confidence (<0.5): 0

# %%
model_bin = os.path.join(MODELS_DIR, "autocategorize.bin")
model.save_model(model_bin)
bin_mb = os.path.getsize(model_bin) / 1024 / 1024
print(f"Saved full model: {model_bin} ({bin_mb:.0f} MB)")
# Out:
# Saved full model: /home/rohit/Betopia/Hishab_Spending_Wisely/ml/auto_categorize/models/autocategorize.bin (825 MB)

# %%
FASTTEXT_CLI = shutil.which("fasttext")
if not FASTTEXT_CLI:
    for p in [os.path.expanduser("~/.local/bin/fasttext"), "/tmp/fastText/fasttext"]:
        if os.path.exists(p):
            FASTTEXT_CLI = p
            break
if not FASTTEXT_CLI:
    print("Building fasttext CLI from source ...")
    subprocess.run(["git", "clone", "--depth", "1",
        "https://github.com/facebookresearch/fastText.git", "/tmp/fastText"],
        check=True, capture_output=True)
    subprocess.run(["make"], cwd="/tmp/fastText", check=True, capture_output=True)
    FASTTEXT_CLI = "/tmp/fastText/fasttext"

model_out = os.path.join(MODELS_DIR, "autocategorize")
print("Quantizing model ...")

with tempfile.NamedTemporaryFile(suffix=".txt", delete=False) as tmp:
    qt_txt = tmp.name
    to_fasttext_txt(train_df, qt_txt)

result_q = subprocess.run([
    FASTTEXT_CLI, "quantize",
    "-input", qt_txt,
    "-output", model_out,
    "-qnorm", "-retrain",
    "-epoch", str(QUANTIZE_EPOCH),
    "-dsub", "2",
    "-cutoff", str(QUANTIZE_CUTOFF),
], check=True, capture_output=True, text=True)
os.unlink(qt_txt)
print(result_q.stderr)

model_ftz = model_out + ".ftz"
ftz_kb = os.path.getsize(model_ftz) / 1024
print(f"Quantized model: {model_ftz} ({ftz_kb:.0f} KB)")
# Out:
# Quantizing model ...
#
# Progress:   8.7% words/sec/thread:  192386 lr:  0.045629 avg.loss:  0.003138 ETA:   0h 0m 1s
# Progress:  17.9% words/sec/thread:  199088 lr:  0.041073 avg.loss:  0.003920 ETA:   0h 0m 0s
# Progress:  27.0% words/sec/thread:  201795 lr:  0.036501 avg.loss:  0.004045 ETA:   0h 0m 0s
# Progress:  36.3% words/sec/thread:  203806 lr:  0.031871 avg.loss:  0.004598 ETA:   0h 0m 0s
# Progress:  45.4% words/sec/thread:  204369 lr:  0.027315 avg.loss:  0.004314 ETA:   0h 0m 0s
# Progress:  54.5% words/sec/thread:  203488 lr:  0.022732 avg.loss:  0.004472 ETA:   0h 0m 0s
# Progress:  63.5% words/sec/thread:  202538 lr:  0.018258 avg.loss:  0.004443 ETA:   0h 0m 0s
# Progress:  71.5% words/sec/thread:  200007 lr:  0.014244 avg.loss:  0.004319 ETA:   0h 0m 0s
# Progress:  79.9% words/sec/thread:  198826 lr:  0.010067 avg.loss:  0.004172 ETA:   0h 0m 0s
# Progress:  88.9% words/sec/thread:  199259 lr:  0.005558 avg.loss:  0.004045 ETA:   0h 0m 0s
# Progress:  96.6% words/sec/thread:  196872 lr:  0.001712 avg.loss:  0.004003 ETA:   0h 0m 0s
# Progress: 100.0% words/sec/thread:  187012 lr: -0.000007 avg.loss:  0.003994 ETA:   0h 0m 0s
# Progress: 100.0% words/sec/thread:  187000 lr:  0.000000 avg.loss:  0.003994 ETA:   0h 0m 0s
#
# Quantized model: /home/rohit/Betopia/Hishab_Spending_Wisely/ml/auto_categorize/models/autocategorize.ftz (5979 KB)

# %%
print("Quantized model - unseen notes:\n")
q_correct = 0
for note, expected in UNSEEN_NOTES:
    pred = subprocess.run(
        f"{FASTTEXT_CLI} predict {model_ftz} - 1",
        input=note, capture_output=True, text=True, check=True, shell=True
    )
    label = pred.stdout.strip().replace("__label__", "")
    correct = "Y" if label == expected else "X"
    if label == expected:
        q_correct += 1
    print(f"  {correct} {note:55s} expected={expected:<20} -> {label}")

print(f"\nQuantized unseen accuracy: {q_correct}/{len(UNSEEN_NOTES)} = {q_correct/len(UNSEEN_NOTES)*100:.1f}%")
# Out:
# Quantized model - unseen notes:
#
#   X went school                                             expected=Education            -> Entertainment
#   Y to office                                               expected=Transportation       -> Transportation
#   Y kfc lunch                                               expected=Food_and_Dining      -> Food_and_Dining
#   Y market for vegetables                                   expected=Groceries            -> Groceries
#   Y just milk and bread                                     expected=Groceries            -> Groceries
#   Y sylhet trip                                             expected=Travel               -> Travel
#   Y home from airport                                       expected=Transportation       -> Transportation
#   Y nikah ceremony gift                                     expected=Others               -> Others
#   X bhai er biye                                            expected=Others               -> Food_and_Dining
#   Y uber                                                    expected=Transportation       -> Transportation
#   Y rent                                                    expected=Rent_and_Housing     -> Rent_and_Housing
#   Y lunch                                                   expected=Food_and_Dining      -> Food_and_Dining
#   Y groceries                                               expected=Groceries            -> Groceries
#   Y electricity                                             expected=Utilities            -> Utilities
#   Y netflix                                                 expected=Entertainment        -> Entertainment
#   Y pathao                                                  expected=Transportation       -> Transportation
#   Y kfc                                                     expected=Food_and_Dining      -> Food_and_Dining
#   X agora                                                   expected=Groceries            -> Shopping
#   X starbucks                                               expected=Food_and_Dining      -> Entertainment
#   X daraz                                                   expected=Shopping             -> Groceries
#   X bKash                                                   expected=Others               -> Food_and_Dining
#   Y ubr to dhanmondi                                        expected=Transportation       -> Transportation
#   Y cng gulsan 200                                          expected=Transportation       -> Transportation
#   Y rksw ofc                                                expected=Transportation       -> Transportation
#   Y grceries frm shwapno                                    expected=Groceries            -> Groceries
#   Y kacchi bhai                                             expected=Food_and_Dining      -> Food_and_Dining
#   Y mbl rchrg gp                                            expected=Utilities            -> Utilities
#   Y elec bill nov                                           expected=Utilities            -> Utilities
#   Y bazare alu peyaj                                        expected=Groceries            -> Groceries
#   Y dr. visit cardiologist                                  expected=Health_and_Medical   -> Health_and_Medical
#   Y meds from pharmacy                                      expected=Health_and_Medical   -> Health_and_Medical
#   Y lunch at kfC                                            expected=Food_and_Dining      -> Food_and_Dining
#   Y groceries from swapno                                   expected=Groceries            -> Groceries
#   Y ubber to airport                                        expected=Transportation       -> Transportation
#   Y medecine for cough                                      expected=Health_and_Medical   -> Health_and_Medical
#   Y elektricity bill                                        expected=Utilities            -> Utilities
#   X restuarent dinner                                       expected=Food_and_Dining      -> Entertainment
#   X birthday gft for friend                                 expected=Shopping             -> Others
#   Y stationary for skool                                    expected=Education            -> Education
#   Y chicken biriyani from kacchi bhai                       expected=Food_and_Dining      -> Food_and_Dining
#   X cigarete                                                expected=Others               -> Entertainment
#   X overpriced garbage at that restaurant                   expected=Food_and_Dining      -> Travel
#   Y best biryani ever                                       expected=Food_and_Dining      -> Food_and_Dining
#   Y never going back to that salon                          expected=Personal_Care        -> Personal_Care
#   X waste of money honestly                                 expected=Others               -> Entertainment
#   X emergency had to fix the pipe                           expected=Rent_and_Housing     -> Health_and_Medical
#   Y rip off 500 for a haircut                               expected=Personal_Care        -> Personal_Care
#   Y kacchi bhai er dokan e lunch                            expected=Food_and_Dining      -> Food_and_Dining
#   Y bhat and daal for dinner                                expected=Food_and_Dining      -> Food_and_Dining
#   Y shobji from karwan bazar                                expected=Groceries            -> Groceries
#   Y bazar korechi aj                                        expected=Groceries            -> Groceries
#   X dudh ar dim                                             expected=Groceries            -> Food_and_Dining
#   Y danmondi te uber 150                                    expected=Transportation       -> Transportation
#   Y phone recharge gp 150 taka                              expected=Utilities            -> Utilities
#   X biraler khabar kinechi                                  expected=Shopping             -> Food_and_Dining
#   Y yesterday dinner                                        expected=Food_and_Dining      -> Food_and_Dining
#   Y last week grocery                                       expected=Groceries            -> Groceries
#   Y today lunch                                             expected=Food_and_Dining      -> Food_and_Dining
#   Y this month electricity                                  expected=Utilities            -> Utilities
#   Y last month rent                                         expected=Rent_and_Housing     -> Rent_and_Housing
#   Y january er bill                                         expected=Utilities            -> Utilities
#   Y previous month internet                                 expected=Utilities            -> Utilities
#   Y coffee and a book                                       expected=Entertainment        -> Entertainment
#   X fuel and lunch                                          expected=Transportation       -> Food_and_Dining
#   Y medicine for mother                                     expected=Others               -> Others
#   Y bus ticket to sylhet                                    expected=Travel               -> Travel
#   X coffee at north end                                     expected=Entertainment        -> Food_and_Dining
#   Y car servicing and wash                                  expected=Transportation       -> Transportation
#   Y netflix and dinner                                      expected=Entertainment        -> Entertainment
#   Y bought a gift and groceries                             expected=Shopping             -> Shopping
#   Y spotify and a book                                      expected=Entertainment        -> Entertainment
#   Y parking and fuel                                        expected=Transportation       -> Transportation
#   X 500                                                     expected=Others               -> Food_and_Dining
#   Y paid 1200 for dinner                                    expected=Food_and_Dining      -> Food_and_Dining
#   Y tk 350 for rickshaw                                     expected=Transportation       -> Transportation
#   Y bdt 1500 for grocery                                    expected=Groceries            -> Groceries
#   Y electricity bill 3200 taka                              expected=Utilities            -> Utilities
#   Y recharged 200 mb 80 tk                                  expected=Utilities            -> Utilities
#   Y misc                                                    expected=Others               -> Others
#   X stuff                                                   expected=Others               -> Entertainment
#   X things                                                  expected=Others               -> Food_and_Dining
#   X bought something                                        expected=Shopping             -> Entertainment
#   Y paid bill                                               expected=Utilities            -> Utilities
#   Y shopping                                                expected=Shopping             -> Shopping
#   X necessities                                             expected=Groceries            -> Entertainment
#   X xyz                                                     expected=Others               -> Food_and_Dining
#   Y item                                                    expected=Others               -> Others
#   Y kfc: zinger 450, fries 150, pepsi 80 = 680 bdt          expected=Food_and_Dining      -> Food_and_Dining
#   Y trip to cox bazar: bus 1200, hotel 3000, food 2500      expected=Travel               -> Travel
#   Y monthly tuition at udvash centre                        expected=Education            -> Education
#   Y eid shopping: 3 panjabi, 2 sharee                       expected=Shopping             -> Shopping
#   Y hospital: cardiologist 1500, ecg 800, medicine 3200     expected=Health_and_Medical   -> Health_and_Medical
#   Y dhaka jabo                                              expected=Transportation       -> Transportation
#   Y bazaar                                                  expected=Groceries            -> Groceries
#   Y bhat                                                    expected=Food_and_Dining      -> Food_and_Dining
#   X oshudh                                                  expected=Health_and_Medical   -> Transportation
#   Y ki jani                                                 expected=Others               -> Others
#
# Quantized unseen accuracy: 74/97 = 76.3%

# %%
print(f"Full model:    {model_bin} ({bin_mb:.0f} MB)")
print(f"Quantized:     {model_ftz} ({ftz_kb:.0f} KB)")

# %%
accuracy_pct = accuracy * 100
print(f"""
## Summary

| Metric | Full Model | Quantized |
|--------|-----------|-----------|
| Size | {bin_mb:.0f} MB | {ftz_kb:.0f} KB |
| Accuracy | {accuracy_pct:.1f}% | - |

Model: {model_ftz}
""")
